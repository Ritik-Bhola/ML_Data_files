# %% [markdown]
# ## MultiCollinearity
#
#
# ### Correlation Plot vs Variance Inflation Matrix

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\admin\\IBM_Training\\Training\\ML Algorithms\\BMI.csv")
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
data["Gender"]=data["Gender"].map({"Male":0,"Female":1})
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0       0     174      96      4
# 1       0     189      87      2
# 2       1     185     110      4
# 3       1     195     104      3
# 4       0     149      61      3

# %%
X=data.iloc[:,:-1]
X.head()
# Out:
#    Gender  Height  Weight
# 0       0     174      96
# 1       0     189      87
# 2       1     185     110
# 3       1     195     104
# 4       0     149      61

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(dataset):
    vif=pd.DataFrame()
    vif["Column"]=dataset.columns
    vif["VIF"]=[variance_inflation_factor(dataset.values,i) for i in range(dataset.shape[1])]
    
    return vif
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
calculate_vif(X)
# Out:
#    Column        VIF
# 0  Gender   2.028864
# 1  Height  11.623103
# 2  Weight  10.688377

# %%
sb.heatmap(X.corr(),annot=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-348bd18c9aed> in <module>
# ----> 1 sb.heatmap(X.corr(),annot=True);
#
# NameError: name 'sb' is not defined

# %% [markdown]
# ***height and weight have very high values of VIF, indicating that these two variables are highly correlated. This is expected as the height of a person does influence their weight. Hence, considering these two features together leads to a model with high multicollinearity.***

# %%
data1=pd.read_csv("C:\\Users\\admin\\IBM_Training\\Training\\ML Algorithms\\HR_data.csv")
data1.head()
data1=data1.iloc[:,:-2]
data1.head()

# %%
calculate_vif(data1)

# %% [markdown]
# # A wider approach of VIF v/s Correlation

# %%
house=pd.read_csv("C:\\Users\\admin\\IBM_Training\\Training\\ML Algorithms\\House Sales.csv")
house.head()
# Out:
#    Interior(Sq Ft)  # of Bed  # of Bath  # of Rooms  Condo Fee   Tax  \
# 0                0         2          1           4         70   490
# 1              850         2          1           5        100   923
# 2              730         2          1           4        185   575
# 3             1058         3          1           5        163  1682
# 4             1585         2          1           6        100  1402
#
#    Sale Price
# 0     1,06,000
# 1     95000.00
# 2     1,31,000
# 3     1,25,000
# 4     79000.00

# %%
def vif_score(dataset):
    vif=pd.DataFrame()
    vif["Independent_Feautes"]=dataset.columns
    vif["VIF_Value"]=[variance_inflation_factor(dataset.values,i) for i in range(dataset.shape[1])]
    return vif

# %%
df1=house.iloc[:,:-1]
df1.head()

# %%
vif_score(df1)
# Out:
#   Independent_Feautes  VIF_Value
# 0     Interior(Sq Ft)  35.436502
# 1            # of Bed  30.207875
# 2           # of Bath  12.254030
# 3          # of Rooms  41.654966
# 4           Condo Fee   9.023152
# 5                 Tax  11.603921

# %%
df1.corr()
# Out:
#                  Interior(Sq Ft)  # of Bed  # of Bath  # of Rooms  Condo Fee  \
# Interior(Sq Ft)         1.000000  0.730519   0.563361    0.771653   0.292240
# # of Bed                0.730519  1.000000   0.376967    0.848883   0.060231
# # of Bath               0.563361  0.376967   1.000000    0.298794   0.460524
# # of Rooms              0.771653  0.848883   0.298794    1.000000   0.046960
# Condo Fee               0.292240  0.060231   0.460524    0.046960   1.000000
# Tax                     0.592464  0.393161   0.541821    0.377941   0.729429
#
#                       Tax
# Interior(Sq Ft)  0.592464
# # of Bed         0.393161
# # of Bath        0.541821
# # of Rooms       0.377941
# Condo Fee        0.729429
# Tax              1.000000

# %% [markdown]
# The VIF scores are higher than 10 for most of the variables. The individual coefficients and the p-values will be greatly impacted if we build a regression model with this dataset. We will proceed on how to fix this issue.

# %% [markdown]
# #### Fixing Multi-Collinearity --- Dropping Variables

# %% [markdown]
# We will consider dropping the features Interior(Sq Ft) and # of Rooms which are having high VIF values because the same information is being captured by other variables. Also, it helps to reduce the redundancy in the dataset.

# %%
df2=df1.copy()
df2.drop(columns=["Interior(Sq Ft)","# of Rooms"],inplace=True)

# %%
df2.head()
# Out:
#    # of Bed  # of Bath  Condo Fee   Tax
# 0         2          1         70   490
# 1         2          1        100   923
# 2         2          1        185   575
# 3         3          1        163  1682
# 4         2          1        100  1402

# %%
vif_score(df2)
# Out:
#   Independent_Feautes  VIF_Value
# 0            # of Bed   7.515687
# 1           # of Bath  10.411790
# 2           Condo Fee   8.582383
# 3                 Tax  10.240541

# %%
vif_score(df1).sort_values(by="VIF_Value",ascending=False)
# Out:
#   Independent_Feautes  VIF_Value
# 3          # of Rooms  41.654966
# 0     Interior(Sq Ft)  35.436502
# 1            # of Bed  30.207875
# 2           # of Bath  12.254030
# 5                 Tax  11.603921
# 4           Condo Fee   9.023152

# %% [markdown]
# From the above, we can notice that the VIF scores have reduced for other variables also after dropping the high-value (Interior(Sq Ft) and # of Rooms) VIF features.

# %% [markdown]
# #### Fixing Multi-Collinearity ---- Combining Variables

# %%
df3=df1.copy()
df3.head()
# Out:
#    Interior(Sq Ft)  # of Bed  # of Bath  # of Rooms  Condo Fee   Tax
# 0                0         2          1           4         70   490
# 1              850         2          1           5        100   923
# 2              730         2          1           4        185   575
# 3             1058         3          1           5        163  1682
# 4             1585         2          1           6        100  1402

# %%
df3["Total_Rooms"]=df3["# of Bed"]+df3["# of Bath"]
df3.head()
df3.drop(columns=["Interior(Sq Ft)","# of Rooms","# of Bed","# of Bath"],inplace=True)
df3.head()
# Out:
#    Condo Fee   Tax  Total_Rooms
# 0         70   490            3
# 1        100   923            3
# 2        185   575            3
# 3        163  1682            4
# 4        100  1402            3

# %%
df3.head()
vif_score(df3)
# Out:
#   Independent_Feautes  VIF_Value
# 0           Condo Fee   7.472693
# 1                 Tax  10.167316
# 2         Total_Rooms   5.466786

# %% [markdown]
# Now that we have reduced VIF score for both df1 and df2. Now let's make a Linear Regression Model to check the r2 values. On original Data, df1 and df2

# %% [markdown]
# ## Linear Regression Model on Original Data, df1 and df2

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
house.head()
#df1.head()
#df2.head()
# Out:
#    Interior(Sq Ft)  # of Bed  # of Bath  # of Rooms  Condo Fee   Tax  \
# 0                0         2          1           4         70   490
# 1              850         2          1           5        100   923
# 2              730         2          1           4        185   575
# 3             1058         3          1           5        163  1682
# 4             1585         2          1           6        100  1402
#
#    Sale Price
# 0     1,06,000
# 1       95,000
# 2     1,31,000
# 3     1,25,000
# 4       79,000

# %% [markdown]
# #### House Data / Original Data

# %%
X=house.iloc[:,:-1]
X.head()
yy=house.iloc[:,6]
yy
# Out:
# 0      1,06,000
# 1      95000.00
# 2      1,31,000
# 3      1,25,000
# 4      79000.00
#          ...
# 451    2,80,000
# 452    2,70,000
# 453    1,85,000
# 454    2,90,000
# 455    2,49,500
# Name:  Sale Price , Length: 456, dtype: object

# %%
y=[pd.to_numeric((yy[i].replace(",",""))) for i in range(yy.shape[0])]
y
# Out:
# [106000,
#  95000.0,
#  131000,
#  125000,
#  79000.0,
#  135000,
#  118000,
#  154000,
#  111500,
#  445000,
#  128500,
#  154000,
#  142000,
#  143000,
#  212500,
#  149000,
#  125000,
#  189000,
#  202000,
#  206000,
#  175000,
#  208000,
#  136500,
#  166000,
#  97000.0,
#  75000.0,
#  205000,
#  172500,
#  179000,
#  105000,
#  166000,
#  150700,
#  166000,
#  145000,
#  122000,
#  135000,
#  165000,
#  214500,
#  152000,
#  165000,
#  142000,
#  89000.0,
#  133000,
#  144000,
#  110000,
#  120000,
#  101000,
#  125000,
#  121000,
#  119500,
#  138500,
#  110000,
#  160000,
#  179000,
#  100000,
#  505000,
#  215000,
#  530000,
#  400000,
#  380000,
#  535000,
#  225000,
#  370000,
#  575000,
#  875000,
#  440000,
#  460000,
#  116500,
#  153000,
#  162000,
#  132500,
#  139000,
#  129000,
#  82882.0,
#  106000,
#  106000,
#  261000,
#  260000,
#  255000,
#  256000,
#  261000,
#  240000,
#  231500,
#  265000,
#  200000,
#  178000,
#  240000,
#  274500,
#  112000,
#  177000,
#  134000,
#  160000,
#  195000,
#  222500,
#  180000,
#  148000,
#  160000,
#  136000,
#  149000,
#  395000,
#  376500,
#  218000,
#  186000,
#  205000,
#  105000,
#  163000,
#  109000,
#  132000,
#  147000,
#  141000,
#  215000,
#  105000,
#  160000,
#  187500,
#  261000,
#  73000.0,
#  217000,
#  250000,
#  235000,
#  247000,
#  87000.0,
#  100500,
#  171000,
#  130000,
#  79000.0,
#  103500,
#  98000.0,
#  101000,
#  77000.0,
#  141800,
#  133000,
#  132000,
#  97500.0,
#  147000,
#  82000.0,
#  180000,
#  192500,
#  127000,
#  103000,
#  79000.0,
#  80000.0,
#  305000,
#  175000,
#  97400.0,
#  115000,
#  151000,
#  205000,
#  126000,
#  165000,
#  252000,
#  260000,
#  191000,
#  162000,
#  68000.0,
#  120000,
#  185000,
#  235000,
#  181000,
#  259000,
#  194000,
#  200000,
#  210000,
#  112000,
#  155000,
#  158000,
#  129000,
#  104000,
#  91250.0,
#  93000.0,
#  161000,
#  155000,
#  172500,
#  115000,
#  166500,
#  141000,
#  155000,
#  160000,
#  131000,
#  170000,
#  182000,
#  130000,
#  151750,
#  172000,
#  120000,
#  104000,
#  118000,
#  139000,
#  97000.0,
#  80250.0,
#  114500,
#  105000,
#  93000.0,
#  95000.0,
#  105500,
#  92000.0,
#  85000.0,
#  139500,
#  126000,
#  121000,
#  104000,
#  141300,
#  142500,
#  170000,
#  155000,
#  155800,
#  146000,
#  390000,
#  220000,
#  135000,
#  187000,
#  110000,
#  110000,
#  135000,
#  167000,
#  170000,
#  222000,
#  125000,
#  51000.0,
#  62000.0,
#  53500.0,
#  69000.0,
#  200000,
#  198000,
#  250000,
#  214000,
#  245500,
#  138000,
#  135000,
#  170000,
#  105000,
#  106000,
#  105000,
#  159000,
#  145000,
#  118500,
#  100000,
#  113900,
#  207500,
#  293000,
#  190000,
#  166000,
#  260000,
#  177000,
#  155500,
#  156000,
#  288000,
#  85500.0,
#  186000,
#  160000,
#  148000,
#  89000.0,
#  144000,
#  114000,
#  140000,
#  152500,
#  259000,
#  88000.0,
#  129900,
#  75000.0,
#  210000,
#  188500,
#  120000,
#  165000,
#  168000,
#  166000,
#  115000,
#  118000,
#  140000,
#  133100,
#  139000,
#  155000,
#  187500,
#  191500,
#  191300,
#  209000,
#  180000,
#  116500,
#  145000,
#  125000,
#  210000,
#  212500,
#  225000,
#  127500,
#  260000,
#  146000,
#  120000,
#  172500,
#  305000,
#  79900.0,
#  72000.0,
#  72000.0,
#  76500.0,
#  200000,
#  172500,
#  149500,
#  215000,
#  187500,
#  182500,
#  230000,
#  258000,
#  210000,
#  131000,
#  126000,
#  94500.0,
#  102000,
#  110000,
#  615000,
#  625000,
#  115000,
#  86000.0,
#  139000,
#  85000.0,
#  153000,
#  136000,
#  210000,
#  250000,
#  265000,
#  315000,
#  455000,
#  300000,
#  370000,
#  400000,
#  172000,
#  185000,
#  180000,
#  141000,
#  295000,
#  272500,
#  259000,
#  165000,
#  180000,
#  171500,
#  172000,
#  158500,
#  137000,
#  163500,
#  170000,
#  185500,
#  153000,
#  132000,
#  145500,
#  180000,
#  155000,
#  127000,
#  139000,
#  134000,
#  121500,
#  139000,
#  90000.0,
#  107500,
#  123000,
#  142000,
#  156000,
#  135000,
#  169000,
#  118000,
#  156000,
#  79000.0,
#  121500,
#  114000,
#  115000,
#  124000,
#  133000,
#  118000,
#  183000,
#  126000,
#  145000,
#  135000,
#  190000,
#  210000,
#  212500,
#  310000,
#  300000,
#  390000,
#  295000,
#  396600,
#  220000,
#  381463,
#  198500,
#  270000,
#  166000,
#  127500,
#  66000.0,
#  290000,
#  250000,
#  89000.0,
#  121000,
#  212000,
#  159000,
#  178000,
#  210000,
#  157000,
#  252000,
#  175000,
#  220000,
#  150000,
#  93500.0,
#  104000,
#  92500.0,
#  290000,
#  270000,
#  155000,
#  151700,
#  117000,
#  175000,
#  218000,
#  115000,
#  71000.0,
#  110000,
#  90000.0,
#  62000.0,
#  105000,
#  99500.0,
#  133500,
#  154000,
#  113500,
#  290000,
#  108000,
#  91000.0,
#  134500,
#  275000,
#  104500,
#  137000,
#  143000,
#  138000,
#  121000,
#  125333,
#  110000,
#  114000,
#  135000,
#  100000,
#  85000.0,
#  100000,
#  117000,
#  103000,
#  119000,
#  108000,
#  117000,
#  105000,
#  120000,
#  176000,
#  129500,
#  125000,
#  122000,
#  119900,
#  108900,
#  150000,
#  155750,
#  116500,
#  186500,
#  148000,
#  280000,
#  270000,
#  185000,
#  290000,
#  249500]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(X_test)

# %%
r2_score(y_test,pred)
# Out:
# 0.08931368639938797

# %% [markdown]
# ## Df2 Data

# %%
df2.head()
X=df2.copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

lr.fit(X_train,y_train)

df2_pred=lr.predict(X_test)
r2_score(y_test,df2_pred)
# Out:
# 0.09280646314291163

# %% [markdown]
# ## Df3 Data

# %%
df3.head()

X=df3.copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

lr.fit(X_train,y_train)

df3_pred=lr.predict(X_test)
r2_score(y_test,df3_pred)
# Out:
# 0.10177054571896804

# %%
#For a better view 
print(r2_score(y_test,pred),"Accuracy from Original Data")

print()

print(r2_score(y_test,df2_pred),"Accuracy from Df2 Data where 2 columns were deleted")

print()

print(r2_score(y_test,df3_pred),"Accuracy from df3 Data where 2 columns were delete and 2 columns were combined")
# Out:
# 0.08931368639938797 Accuracy from Original Data
#
# 0.09280646314291163 Accuracy from Df2 Data where 2 columns were deleted
#
# 0.10177054571896804 Accuracy from df3 Data where 2 columns were delete and 2 columns were combined

# %% [markdown]
# # Thank You
